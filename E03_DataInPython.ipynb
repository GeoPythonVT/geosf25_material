# %% [markdown]
# Geo Data Science with Python,
# Prof. Susanna Werth, VT Geosciences
#
# ---
# **Exercise 3**
# # **Hierarchical Data in Python**
#
# ---

# %% [markdown]
# ## Grading Scheme
#
# You will receive the following points for this exercise:
#
# 1) 25 P - Gistemp Dataset (Tutorial 1-8)
# 2) 25 P - SST Dataset (Tutorial 9)
#
# Total: 50P (equal 100%)
#
# ---

# %% [markdown]
# ### Earthdata.org
# Before next class, please make an account on NASA's Earthdata.org. Note down your password and username and bring them to the next class.

# %% [markdown]
# ---
# ## Tutorial 1-8
#
# Complete the entire Tutorial 1-8 from class L03. Summarize only the answers to all the questions in a markdown cell below. Below, include code for generating and actually insert a plot of the temperatures in August 2025 and a time series of the global mean temperature for the entire dataset.

# %% [markdown]
# Anwers to the questions of Tutorial 1

# %% [markdown]
# Anwers to the questions of Tutorial 2

# %% [markdown]
# Anwers to the questions of Tutorial 3

# %% [markdown]
# Anwers to the questions of Tutorial 4

# %% [markdown]
# Anwers to the questions of Tutorial 5

# %% [markdown]
# Anwers to the questions of Tutorial 7

# %% [markdown]
# Anwers to the questions of Tutorial 7

# %% [markdown]
# Anwers to the questions of Tutorial 8

# %%
# YOUR CODE SOLUTION HERE

# %% [markdown]
# ---
# ## Tutorial 9

# %% [markdown]
# ### Data
# We will downloaded a [sample netCDF file from the website of the University Corporation for Atmospheric Research (UCAR)](https://archive.unidata.ucar.edu/software/netcdf/examples/files.html).
# The file is named `tos_O1_2001-2002.nc`. The link to the download page is https://www.unidata.ucar.edu/software/netcdf/examples/files.html.
# It provides 24 time steps of sea surface temperatures collected for use by the IPCC. For this exercise we are looking into a tiny fraction of the dataset for this exerciese: the years 2001 and 2002. The dataset has a spatial resolution of 2 degree in longitudinal and 1 degree in latitudinal direction.

# %% [markdown]
# ### Tasks
#
# Read and self-inspect the data. Then calculate the maximum sea surface temperature during the year 2001 for each gridpoint. Then print the resulting map.
#
# * Download the data with python code, use the module **requests** or the module **urllib**.
# * Import the package `Dataset` from the module netCDF4
# * Read the netcdf dataset from the file `tos_O1_2001-2002.nc` and save the content to a new variable `data`
# * Print out the information of the dataset to get an overview. Explore & discuss the content of the dataset
# * Assign each relevant variable to a new array.
# * Close the netCDF dataset/file
# * Convert the 1D coordinate arrays to a meshgrid arrays and save them to the variables `lat_grid` and `lon_grid`
# * Converting missing values in `tos` data to `np.nan` (convert to Celsius or leave at Kelvin, as you prefer)
# * Estimate and plto a time series of the monthly mean SST for the northern and southern hemisphere using vectorized code.
# * What do you observe from the time series?
# * Estimate the El Nino 3.4 Index and plot a time series of it. Find a definition of the 3.4 index here: https://climatedataguide.ucar.edu/climate-data/nino-sst-indices-nino-12-3-34-4-oni-and-tni  To estimate a 5-month moving average use the code example below.
# * Discuss if an extreme (La Nina or El Nino) event took place during either of the two years we have data available.
#
#
# ```python
# ## Code example to estimate a smoothed version of the time series stored in the variable 'numpyVector'
# import pandas as pd
# data = pd.Series(numpyVector)  # this example uses pandas and creates a pandas series
#
# # Moving average (window size = 7)
# smoothed = data.rolling(window=7, center=True).mean()  # pandas has a method rolling, useful for performing window smoothing
# ```

# %%
# YOUR CODE SOLUTION HERE
