# %% [markdown]
# Geo Data Science with Python,
# Prof. Susanna Werth, VT Geosciences
#
# ---
# **Exercise 8**
# # Time Series Analysis
#
# ---

# %% [markdown]
# ## Grading Scheme
#
# You will receive the following points for this exercise:
#
# - **A.** Basics: Smoothing, Auto- & Cross-Correlations
#     - A1: 4P
#     - A2: 5P
#     - A3: 3P
#     - A4(EC): 4P
#
# - **B.** Fourier Transform & Harmonic Models
#     - B1: 4P
#     - B2: 5P
#     - B3 (EC): 5P
#
# - **C.** Using Real Data
#     - C1: 6P
#     - C2: 10P
#     - C3: 10P
#     - C4: 3P
#     - C5 (EC): 5P
#     - C6 (EC): 6P
#
# Total: 55P (equal 100%)
# Possible extra credit: 20P
#
# ---

# %% [markdown]
# ## Tasks
#
# Copy paste the exercise tasks from `L08_tutorial_TimeSeries.ipynb` below and add your code solutions, answers and discussions.

# %%
add cells here...
