# %% [markdown]
# Geo Data Science with Python,
# Prof. Susanna Werth, VT Geosciences
#
# ---
# **Exercise 10**
# # Unsupervised ML
#
# ---

# %% [markdown]
# ## Grading Scheme
#
# You will receive the following points for this exercise:
#
# - **C.** Sea Surface Temperatures
#     - C.1: 20P
#     - C.2: 10P
#     - C.3: 20P
#
# Total: 50P (equal 100%)
#
# ---

# %% [markdown]
# ## Tasks
#
# Copy paste the exercise tasks from `L10_tutorial_TimeSeries.ipynb` below and add your code solutions, answers and discussions.

# %%
add cells here...
