# %% [markdown]
# Geo Data Science with Python,
# Prof. Susanna Werth, VT Geosciences
#
# ---
# **Exercise 1**
# # **A taste of Jupyter Notebooks and Python**
#
# ---

# %% [markdown]
# ## Grading Scheme
#
# You will receive the following points for this exercise:
#
# 1) 10P: Handed in a newly created and neatly organized notebook `E01_<YOUR-PID>.ipynb`.
# 2) 5P: Answer task 2 via a paragraph of at least 3-4 meaningful sentences.
# 3) 10P: Formulated an useful algorithm for solving a puzzle including at least 5 steps.
# 4) 25P: Completed all coding task, and submitted the completed file `myModule_<YOUR-PID>.py`.
#
# Total: 50P (equal 100%)

# %% [markdown]
# ## Instructions
#
# ### Task 1 - *Notebooks*
#
# Study the notebook `L01_reading_MarkdownAndMagic.ipynb`. Then, create a completely new jupyter notebook. It is up to you if you work on Jupyter Lab or Google Colab. The notebook should include:
#
# - a header with information about the notebook,
# - a highlighted box that indicates your name,
# - embed a link to the Geoscience Department website,
# - a title of your choice,
# - and multiple sections to answer the following tasks, include headers, markdown and code cells as required to structure your notebook neatly.

# %% [markdown]
# ### Task 2 - *Python Philosophy*
# Inspect content of the module `this` by executing
# ```python
# import this
# ```
# in a code cell (see below). What is the eights line of the poem and how do you interpret it in the context of writing computer algorithms?

# %% [markdown]
# ### Task 3 - *Algorithms*
#
# Develop an algorithm for solving a jigsaw (physical picture) puzzle. You can formulate the algorithm in worded phrases, pseudocode, or a flowchart. Include as many flow-through steps as required, but at least five.
#
#    This does not have to be perfect, but it should adhere to the basic concepts as much as possible. Formulate steps that structure the problem into smaller steps; these steps should be definite (unambiguous), finite (able to complete), result in correct output, efficient (create some repeatable sequences, focus on the most important aspects).

# %% [markdown]
# ### Task 4 - *Pyton Basics: Write your own Module/script*
#
# If you need to refresh your knowledge on modules, review the Basic Tutorial `B06_reading_Modules.ipynb`.
#
# Now, write a new module file `myModule_<PID>.py` that includes the following elements:
#
# - A docstring including information about your module/script.
# - Defines a global list of name `mylist` that stores any 10 unsorted numbers. If needed, review the basic tutorial `B01_reading_BasicObjectTypes.ipynb`.
# - A function of name `mysort()` that receives the list and sort it from small to large. It should mutate the list to a sorted list. (You do not need to write a sorting algorithm, but apply a built-in function that does that.) It would be great if you can find out which algorithm it uses.
# - A main function that applies the just defined list variable and function to sort the list. It should print out the sorted list and provide the information, which sorting algorithm was used.
# - Include an if-statement that excutes the main function only, if the script/module is run from the main program level (e.g., via commant `python myModule.py` entered in a shell), but skips that execusion, if the file is imported as a module.
#
# Next, at the end of the jupyter notebook `E01_<YOUR-PID>.ipynb` to be submitted with this homework, add a section with a code cell where you import your module `myModule_<PID>` into that notebook and execute the writeData() function.
#
# Note that the following code is useful to reload a module file, after it was edited:
#
# ```Python
# import importlib
# importlib.reload(myModule)
# ```

# %% [markdown]
# ---
# ### *When you are ready to submit ...*
#
# Once you are done, save the notebook under this exact name: `E01_<YOUR-PID>.ipynb` as well as the module file under this exact name: `myModule_<YOUR-PID>.py` and submit both through Canvas.

# %% [markdown]
# ---
# ## The Zen of Python
# Type “import this” the code cell below, then run it and study the output!

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %% [markdown]
# The import function usually adds packages to your interpreter. The package "this" simply spits out some text. This is an easter egg, which spells out Tim Peters' guidelines to the development of Python code. Source: https://www.python.org/dev/peps/pep-0020/. (BDFL stands for Benevolent Dictator for Life and refers to Guido van Rossum, the developer of Python.)
