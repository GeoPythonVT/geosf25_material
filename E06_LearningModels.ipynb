# %% [markdown]
# Geo Data Science with Python,
# Prof. Susanna Werth, VT Geosciences
#
# ---
# **Exercise 5**
# # Linear Regression Models
#
# ---

# %% [markdown]
# ## Grading Scheme
#
# You will receive the following points for this exercise:
#
# 1) 12 P - Exercise A
# 2) 15 P - Exercise B
# 3) 15 P - Exercise C
# 4) 8 P - Exercise D
#
# Total: 50P (equal 100%)
# Possible extra credit: 20P
#
# ---

# %% [markdown]
# ## Tasks
#
# Copy paste the exercise tasks from `L06_tutorial_LearningModels.ipynb` below and add your code solutions, answers and discussions.

# %%
add cells here...
