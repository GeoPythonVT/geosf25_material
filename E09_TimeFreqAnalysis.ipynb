# %% [markdown]
# Geo Data Science with Python,
# Prof. Susanna Werth, VT Geosciences
#
# ---
# **Exercise 9**
# # Time Frequency Analysis
#
# ---

# %% [markdown]
# ## Grading Scheme
#
# You will receive the following points for this exercise:
#
# - **A.** Non-stationary signals and FFT (total 15P)
#     - A.1: 6P for discussion + 5P for showing results for all signals
#     - A.2: 2P for discussion + 2P for showing one example
#
# - **B.** Wavelet time frequency analysis (total 18P
#     - B.1: 3P for discussion + 2P for showing results for both cases
#     - B.2: 5P for discussion + 3P for showing results for all signals
#     - B.3: 3P for discussion + 2P for showing results for both cases
#     - B.4: 2P (extra credit) for discussion + 2P for showing one example
#
#
#
# - **C.** Decomposing the El Nino Index (total 22P)
#     - C.1: 3P for discussion + 2P for results
#     - C.2: 5P for discussion + 5P for correct CWT setup & results, including COI
#     - C.3: 5P for discussion + 2P for plotting amplitude and phase image
#     - C.4: 6P (extra credit) for discussion
#
# Total: 55P (equal 100%)
# Possible extra credit: 10P
#
# ---

# %% [markdown]
# ## Tasks
#
# Copy paste the exercise tasks from `L09_tutorial_TimeSeries.ipynb` below and add your code solutions, answers and discussions.

# %%
add cells here...
